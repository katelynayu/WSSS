# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime
import math

#import CSV
CS215 = pd.read_csv('/Users/katelynyu/Documents/Github/WSSS/L6_ExcelSheet.csv', low_memory= False)
CS215.head()
# Out:
#       TIMESTAMP  RECORD  BattV_Min  AirTC_1  AirTC_1_Avg   RH_1  RH_1_Avg  \
# 0  9/28/17 7:54       0      12.97     8.53         8.51  77.15     77.10
# 1  9/28/17 7:55       1      12.96     8.55         8.54  76.39     76.59
# 2  9/28/17 7:56       2      12.97     8.59         8.59  76.78     76.65
# 3  9/28/17 7:57       3      12.97     8.63         8.63  76.49     76.62
# 4  9/28/17 7:58       4      12.97     8.69         8.67  75.84     76.03
#
#    AirTC_2  AirTC_2_Avg   RH_2    ...       RH_8  RH_8_Avg  AirTC_9  \
# 0    7.934        7.929  80.60    ...      73.18     73.37     8.56
# 1    8.010        7.999  79.83    ...      72.76     72.77     8.63
# 2    8.050        8.050  79.52    ...      72.91     72.84     8.63
# 3    8.110        8.090  79.37    ...      73.67     73.39     8.69
# 4    8.150        8.140  79.29    ...      74.18     74.09     8.73
#
#    AirTC_9_Avg   RH_9  RH_9_Avg  AirTC_10  AirTC_10_Avg  RH_10  RH_10_Avg
# ...

# %%
WS= pd.read_csv('/Users/katelynyu/Documents/Github/WSSS/L6_WSSS_WeatherStationSS.csv', low_memory = False)
WS.head()
# Out:
#       TIMESTAMP  RECORD  BattV  PTemp_C_Avg  BP_mmHg_Avg  AirTC_WS_Avg  RH_WS  \
# 0  9/28/17 7:55       0  12.96        7.988        678.9          8.18  78.27
# 1  9/28/17 8:00       1  12.97        8.120        764.3          8.35  76.72
# 2  9/28/17 8:05       2  12.98        8.230        764.3          8.61  75.15
# 3  9/28/17 8:10       3  12.98        8.340        764.3          8.94  73.72
# 4  9/28/17 8:15       4  12.98        8.470        764.3          9.34  69.19
#
#   PAR_Den_Avg PAR_Tot_Tot  LWmV_Avg     ...       P_WS2_Avg  PA_WS2_Avg  \
# 0       10.75   0.2149642     268.5     ...           5.705       2.282
# 1       11.02   0.5510034     268.4     ...           5.705       2.282
# 2        11.5   0.5749702     268.3     ...           5.705       2.282
# 3       11.98   0.5989106     268.3     ...           5.705       2.282
# 4        12.6    0.629964     268.3     ...           5.705       2.282
#
# ...

# %%
#CS215 data
date_CS215 = CS215['TIMESTAMP']
temp1_CS215= CS215['AirTC_1_Avg']
RH1_CS215 = CS215['RH_1_Avg']
temp2_CS215= CS215['AirTC_2_Avg']
RH2_CS215 = CS215['RH_2_Avg']
temp3_CS215= CS215['AirTC_3_Avg']
RH3_CS215 = CS215['RH_3_Avg']
temp4_CS215= CS215['AirTC_4_Avg']
RH4_CS215 = CS215['RH_4_Avg']
temp5_CS215= CS215['AirTC_5_Avg']
RH5_CS215 = CS215['RH_5_Avg']
temp6_CS215= CS215['AirTC_6_Avg']
RH6_CS215 = CS215['RH_6_Avg']
temp7_CS215= CS215['AirTC_7_Avg']
RH7_CS215 = CS215['RH_7_Avg']
temp8_CS215= CS215['AirTC_8_Avg']
RH8_CS215 = CS215['RH_8_Avg']
temp9_CS215= CS215['AirTC_9_Avg']
RH9_CS215 = CS215['RH_9_Avg']
temp10_CS215= CS215['AirTC_10_Avg']
RH10_CS215 = CS215['RH_10_Avg']

#in mmHg
pressure = WS['BP_mmHg_Avg']

def barometric_eq(time, height):
    #barometric equation: p = p_0 * e**(-mgh/kT)
    p_0 = pressure[time] #mmHg
    m = .029 #kg/mol
    g = 9.8 #m/s^2
    h = height #m
    k = 8.3144598 #m2 kg s-2 K-1 mol-1
    T = temp1_CS215[time] #K 
    return p_0 * math.exp((-m*g*h)/(k*T))

#list of adjusted pressures at a specific time 
P1 = []
P2 = []
P3 = []
P4 = []
P5 = []
P6 = []
P7 = []
P8 = []
P9 = []
P10 = []

def altpressure(time):
    P1.append(barometric_eq(time, -2.1))
    P2.append(pressure[time])
    P3.append(barometric_eq(time, 2.1))
    P4.append(barometric_eq(time, 4.2))
    P5.append(barometric_eq(time, 6.3))
    P6.append(barometric_eq(time, 8.4))
    P7.append(barometric_eq(time, 10.5))
    P8.append(barometric_eq(time, 12.6))
    P9.append(barometric_eq(time, 14.8))
    P10.append(barometric_eq(time, 17.0))

for i in range(0, 30859):
    altpressure(i)
print(P6)

T1 = []
T2 = []
T3 = []
T4 = []
T5 = []
T6 = []
T7 = []
T8 = []
T9 = []
T10 = []

def temp(time):
    T1.append(temp1_CS215[time]+273.15)
    T2.append(temp2_CS215[time]+273.15)
    T3.append(temp3_CS215[time]+273.15)
    T4.append(temp4_CS215[time]+273.15)
    T5.append(temp5_CS215[time]+273.15)
    T6.append(temp6_CS215[time]+273.15)
    T7.append(temp7_CS215[time]+273.15)
    T8.append(float(temp8_CS215[time])+273.15)
    T9.append(temp9_CS215[time]+273.15)
    T10.append(temp10_CS215[time]+273.15)

for i in range (0, 30859):
        temp(i)
        
print(T1)
# Out:
# [656.3763011894514, 739.03059336770309, 739.17523496357694, 739.28976157308159, 739.40324892004423, 739.48769089430482, 739.65486817202373, 739.8470835351244, 740.06311960441462, 740.3016426561411, 740.4386264002685, 740.48997412235451, 740.61737781522254, 740.76846664958771, 740.99150476598777, 741.08923793771396, 741.25693686038665, 741.51558148738172, 741.76843502195402, 742.06005818389667, 742.25752970182407, 742.37566392400902, 742.66301001195279, 742.77321114627603, 743.01684922588822, 743.27455697447283, 743.58317575755052, 743.74841297060334, 743.96815172633967, 744.16541101724124, 744.45624627923098, 744.54844430088508, 744.67037737188514, 744.94969352442365, 745.01447151438606, 745.18981738012928, 745.29970693595703, 745.42371664470136, 745.34150495547465, 745.53086938608578, 745.47879633552213, 745.68179503066153, 745.7414693954513, 745.84495912988507, 746.00122224558766, 746.01963744825525, 746.26031826872997, 746.16365595957973, 746.34511184891755, 746.39886349636595, 74
# ...

# %%
def svp(T):
    L = 2.5 * math.pow(10,6) #J/kg
    R_v = 461 #J /(kg K)
    return .611 * math.exp((L/R_v)*((1/273)-(1/(T)))) #saturation vapor pressure #kPa 

svp1 = []
svp2 = []
svp3 = []
svp4 = []
svp5 = []
svp6 = []
svp7 = []
svp8 = []
svp9 = []
svp10 = []

def svplist(time):
    svp1.append((svp(temp1_CS215[time]+273.15)) * 760/101.325)
    svp2.append((svp(temp2_CS215[time]+273.15))* 760/101.325)
    svp3.append((svp(temp3_CS215[time]+273.15))* 760/101.325)
    svp4.append((svp(temp4_CS215[time]+273.15))* 760/101.325)
    svp5.append((svp(temp5_CS215[time]+273.15))* 760/101.325)
    svp6.append((svp(temp6_CS215[time]+273.15))* 760/101.325)
    svp7.append((svp(temp7_CS215[time]+273.15))* 760/101.325)
    svp8.append((svp(float(temp8_CS215[time])+273.15))* 760/101.325)
    svp9.append((svp(temp9_CS215[time]+273.15))* 760/101.325)
    svp10.append((svp(temp10_CS215[time]+273.15))* 760/101.325) 

for i in range(0, 30859):
    svplist(i)
print(svp1)

RH1 = []
RH2 = []
RH3 = []
RH4 = []
RH5 = []
RH6 = []
RH7 = []
RH8 = []
RH9 = []
RH10 = []

def RH(time):
    RH1.append(RH1_CS215[time] /100)
    RH2.append(RH2_CS215[time]/100)
    RH3.append(RH3_CS215[time]/100)
    RH4.append(RH4_CS215[time]/100)
    RH5.append(RH5_CS215[time]/100)
    RH6.append(RH6_CS215[time]/100)
    RH7.append(RH7_CS215[time]/100)
    RH8.append(float(RH8_CS215[time])/100)
    RH9.append(RH9_CS215[time]/100)
    RH10.append(RH10_CS215[time]/100)

for i in range(0, 30859):
    RH(i)
print(RH1)
# Out:
# [8.440866131253614, 8.458192042541985, 8.487139391535086, 8.510361155023732, 8.533639836846675, 8.551136274466714, 8.586225612731957, 8.627326197939897, 8.674514080353811, 8.727876756063011, 8.781533354185433, 8.793497100675149, 8.823470377607743, 8.859559106876201, 8.913940167550129, 8.9625297168927, 9.00524005583771, 9.072724742322848, 9.140662070659813, 9.221538849586114, 9.277905305179148, 9.34089644007414, 9.397915645508142, 9.461635726240564, 9.538610338636513, 9.622631875623293, 9.726952389572366, 9.819062258290051, 9.898634286501467, 9.972081931987097, 10.04601707372429, 10.120442544072464, 10.209035970188301, 10.284541147231565, 10.35361553415736, 10.430076683708334, 10.4789965107125, 10.535156243877651, 10.542195115192388, 10.584516796042074, 10.605734598356342, 10.655390895297803, 10.683859235649185, 10.733842642813656, 10.76249844118616, 10.820015482989195, 10.892298472122706, 10.943153320980706, 10.986912159335553, 11.067543477877233, 11.14130363550145, 11.21550325244211
# ...

# %%
def partialpressure(RH, svp): #partial pressure of water vapor 
    return np.multiply(RH,svp)

pp1 = partialpressure(RH1, svp1)
pp2 = partialpressure(RH2, svp2)
pp3 = partialpressure(RH3, svp3)
pp4 = partialpressure(RH4, svp4)
pp5 = partialpressure(RH5, svp5)
pp6 = partialpressure(RH6, svp6)
pp7 = partialpressure(RH7, svp7)
pp8 = partialpressure(RH8, svp8)
pp9 = partialpressure(RH9, svp9)
pp10 = partialpressure(RH10, svp10)

# %%
ad1 = []
ad2 = []
ad3 = []
ad4 = []
ad5 = []
ad6 = []
ad7 = []
ad8 = []
ad9 = []
ad10 = []

def airdensity(pressure, temperature, pp_w):
    #ideal gas equation: rho_humid = (rho_d * M_d + rho_v * M_v) / RT
    P = np.multiply(133.3,pressure)
    R = 8.314 #J/(K·mol)
    rho_d = P - pp_w #
    M_d = 0.028964 #kg/mol
    rho_v = np.multiply(133.3, pp_w)
    M_v = 0.018016 #kg/mol
    T = temperature #K
    return ((np.multiply(rho_d, M_d) + np.multiply(rho_v, M_v))/ np.multiply(R , T))

for i in range(0, 30859):
    ad1.append(airdensity(P1[i], T1[i], pp1[i]))
    ad2.append(airdensity(P2[i], T2[i], pp2[i]))
    ad3.append(airdensity(P3[i], T3[i], pp3[i]))
    ad4.append(airdensity(P4[i], T4[i], pp4[i]))
    ad5.append(airdensity(P5[i], T5[i], pp5[i]))
    ad6.append(airdensity(P6[i], T6[i], pp6[i]))
    ad7.append(airdensity(P7[i], T7[i], pp7[i]))
    ad8.append(airdensity(P8[i], T8[i], pp8[i]))
    ad9.append(airdensity(P9[i], T9[i], pp9[i]))
    ad1.append(airdensity(P10[i], T10[i], pp10[i]))

height = [7.9, 10, 12.1, 14.2, 16.3, 18.4, 20.5, 22.6, 24.7, 26.8]

print(ad1)
# Out:
# [1.1354080104430355, 1.0531245535601517, 1.2771996526027523, 1.184674586500587, 1.2769384511416302, 1.1850580274143805, 1.2767234296291594, 1.1851545087584558, 1.2764605645217213, 1.1853201829755364, 1.2762785409828667, 1.1852307494724579, 1.2759690324374506, 1.1854616512950247, 1.2755655932568928, 1.1857204167634938, 1.2751200199573198, 1.1860620415463963, 1.2746463714717238, 1.186573900503846, 1.2739907276148117, 1.186847528616725, 1.2738795323697134, 1.186934299445314, 1.273603325222749, 1.1871496946166797, 1.2732522970556606, 1.1874063779149702, 1.2728342971812086, 1.1877743274034551, 1.2721331438526997, 1.1878539935003383, 1.2716834225968192, 1.1877910200480282, 1.2710587209837068, 1.1880636284445971, 1.2704473882903642, 1.1884266636688525, 1.2697776560128395, 1.1887219133257567, 1.2692504272893435, 1.1889122341152683, 1.2685152585478037, 1.189010652081115, 1.2682038603710619, 1.1892421250051068, 1.2675318438218461, 1.1892714728005549, 1.266907373014627, 1.1895610364788711, 1.26
# ...

# %%
plt.plot(date_CS215[0:30859], ad1, label = 'Sensor 1', linewidth=.5)
plt.plot(date_CS215[0:30859], ad2, label = 'Sensor 2', linewidth=.5)
plt.plot(date_CS215[0:30859], ad3, label = 'Sensor 3', linewidth=.5)
plt.plot(date_CS215[0:30859], ad4, label = 'Sensor 4', linewidth=.5)
plt.plot(date_CS215[0:30859], ad5, label = 'Sensor 5', linewidth=.5)
plt.plot(date_CS215[0:30859], ad6, label = 'Sensor 6', linewidth=.5)
plt.plot(date_CS215[0:30859], ad7, label = 'Sensor 7', linewidth=.5)
plt.plot(date_CS215[0:30859], ad8, label = 'Sensor 8', linewidth=.5)
plt.plot(date_CS215[0:30859], ad9, label = 'Sensor 9', linewidth=.5)
plt.plot(date_CS215[0:30859], ad10, label = 'Sensor 10', linewidth=.5)
plt.title('air density vs time')
plt.xlabel('air density')
plt.ylabel('height')
grd = plt.grid(True)
plt.xticks(rotation= 60)
#plt.xlim(.005, .0075)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-eafc5ae69f84> in <module>()
# ----> 1 plt.plot(date_CS215[0:30859], ad1, label = 'Sensor 1', linewidth=.5)
#       2 plt.plot(date_CS215[0:30859], ad2, label = 'Sensor 2', linewidth=.5)
#       3 plt.plot(date_CS215[0:30859], ad3, label = 'Sensor 3', linewidth=.5)
#       4 plt.plot(date_CS215[0:30859], ad4, label = 'Sensor 4', linewidth=.5)
#       5 plt.plot(date_CS215[0:30859], ad5, label = 'Sensor 5', linewidth=.5)
#
# /anaconda/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(*args, **kwargs)
#    3316                       mplDeprecation)
#    3317     try:
# -> 3318         ret = ax.plot(*args, **kwargs)
#    3319     finally:
#    3320         ax._hold = washold
#
# /anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...
