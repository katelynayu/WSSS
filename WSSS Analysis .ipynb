# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime

#importing the file and reading each sheet seperately 
CS215 = pd.read_excel('L6_ExcelSheet.xlsx', sheetname = 'CS215s')
CS650 = pd.read_excel('L6_ExcelSheet.xlsx', sheetname = 'CS650s')

def temperaturegraph(title, date, temp):
    plt.figure(figsize=(60,10))
    plt.plot(date, temp)
    plt.title(title + ' - average')
    plt.xlabel('Date')
    plt.ylabel('Air Temperature (C)')
    grd = plt.grid(True)
    ax = plt.gca()
    myFmt = mdates.DateFormatter("%d/%m/%y")
    ax.xaxis.set_major_formatter(myFmt)
    plt.show()
    
def legend(title, yaxis):
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel(yaxis)
    grd = plt.grid(True)
    plt.xticks(rotation= 60)
    ax = plt.gca()
    ax.xaxis.set_major_locator(mdates.MonthLocator())
    ax.xaxis.set_minor_locator(mdates.MonthLocator(bymonthday=5))
    myFmt = mdates.DateFormatter("%m-%d-%Y")
    ax.xaxis.set_major_formatter(myFmt)
    legend = ax.legend(loc='upper left')


#all CS650s
date_CS650 = CS650['TIMESTAMP']
EC1_CS650 = CS650['EC_Avg']
EC2_CS650 = CS650['EC_2_Avg']
EC3_CS650 = CS650['EC_3_Avg']
EC4_CS650 = CS650['EC_4_Avg']
EC5_CS650 = CS650['EC_5_Avg']
EC6_CS650 = CS650['EC_6_Avg']
EC7_CS650 = CS650['EC_7_Avg']
EC8_CS650 = CS650['EC_8_Avg']
EC9_CS650 = CS650['EC_9_Avg']
EC10_CS650 = CS650['EC_10_Avg']
EC11_CS650 = CS650['EC_11_Avg']
EC12_CS650 = CS650['EC_12_Avg']
EC13_CS650 = CS650['EC_13_Avg']
EC14_CS650 = CS650['EC_14_Avg']
EC15_CS650 = CS650['EC_15_Avg']
EC16_CS650 = CS650['EC_16_Avg']
T1_CS650 = CS650['T_Avg']
T2_CS650 = CS650['T_2_Avg']
T3_CS650 = CS650['T_3_Avg']
T4_CS650 = CS650['T_4_Avg']
T5_CS650 = CS650['T_5_Avg']
T6_CS650 = CS650['T_6_Avg']
T7_CS650 = CS650['T_7_Avg']
T8_CS650 = CS650['T_8_Avg']
T9_CS650 = CS650['T_9_Avg']
T10_CS650 = CS650['T_10_Avg']
T11_CS650 = CS650['T_11_Avg']
T12_CS650 = CS650['T_12_Avg']
T13_CS650 = CS650['T_13_Avg']
T14_CS650 = CS650['T_14_Avg']
T15_CS650 = CS650['T_15_Avg']
T16_CS650 = CS650['T_16_Avg']
P1_CS650 = CS650['P_Avg']
P2_CS650 = CS650['P_2_Avg']
P3_CS650 = CS650['P_3_Avg']
P4_CS650 = CS650['P_4_Avg']
P5_CS650 = CS650['P_5_Avg']
P6_CS650 = CS650['P_6_Avg']
P7_CS650 = CS650['P_7_Avg']
P8_CS650 = CS650['P_8_Avg']
P9_CS650 = CS650['P_9_Avg']
P10_CS650 = CS650['P_10_Avg']
P11_CS650 = CS650['P_11_Avg']
P12_CS650 = CS650['P_12_Avg']
P13_CS650 = CS650['P_13_Avg']
P14_CS650 = CS650['P_14_Avg']
P15_CS650 = CS650['P_15_Avg']
P16_CS650 = CS650['P_16_Avg']

#averages of each to put on the south side map  
print (sum(EC1_CS650) / len(EC1_CS650))
print (sum(EC2_CS650) / len(EC2_CS650))
print (sum(EC3_CS650) / len(EC3_CS650))
print (sum(EC4_CS650) / len(EC4_CS650))
print (sum(EC5_CS650) / len(EC5_CS650))
print (sum(EC6_CS650) / len(EC6_CS650))
print (sum(EC7_CS650) / len(EC7_CS650))
print (sum(EC8_CS650) / len(EC8_CS650))
print (sum(EC9_CS650) / len(EC9_CS650))
print (sum(EC10_CS650) / len(EC10_CS650))
print (sum(EC11_CS650) / len(EC11_CS650))
print (sum(EC12_CS650) / len(EC12_CS650))
print (sum(EC13_CS650) / len(EC13_CS650))
print (sum(EC14_CS650) / len(EC14_CS650))
print (sum(EC15_CS650) / len(EC15_CS650))
print (sum(EC16_CS650) / len(EC16_CS650))

print (sum(T1_CS650) / len(T1_CS650))
print (sum(T2_CS650) / len(T2_CS650))
print (sum(T3_CS650) / len(T3_CS650))
print (sum(T4_CS650) / len(T4_CS650))
print (sum(T5_CS650) / len(T5_CS650))
print (sum(T6_CS650) / len(T6_CS650))
print (sum(T7_CS650) / len(T7_CS650))
print (sum(T8_CS650) / len(T8_CS650))
print (sum(T9_CS650) / len(T9_CS650))
print (sum(T10_CS650) / len(T10_CS650))
print (sum(T11_CS650) / len(T11_CS650))
print (sum(T12_CS650) / len(T12_CS650))
print (sum(T13_CS650) / len(T13_CS650))
print (sum(T14_CS650) / len(T14_CS650))
print (sum(T15_CS650) / len(T15_CS650))
print (sum(T16_CS650) / len(T16_CS650))

print (sum(P1_CS650) / len(P1_CS650))
print (sum(P2_CS650) / len(P2_CS650))
print (sum(P3_CS650) / len(P3_CS650))
print (sum(P4_CS650) / len(P4_CS650))
print (sum(P5_CS650) / len(P5_CS650))
print (sum(P6_CS650) / len(P6_CS650))
print (sum(P7_CS650) / len(P7_CS650))
print (sum(P8_CS650) / len(P8_CS650))
print (sum(P9_CS650) / len(P9_CS650))
print (sum(P10_CS650) / len(P10_CS650))
print (sum(P11_CS650) / len(P11_CS650))
print (sum(P12_CS650) / len(P12_CS650))
print (sum(P13_CS650) / len(P13_CS650))
print (sum(P14_CS650) / len(P14_CS650))
print (sum(P15_CS650) / len(P15_CS650))
print (sum(P16_CS650) / len(P16_CS650))
# Out:
# 0.00759498347268
# 0.00762784367101
# 0.00718014777367
# 0.0105036943418
# 0.00658535874003
# 0.00632412988528
# 0.0088345323741
# 0.0241693564068
# 0.0320817616177
# 0.0103671009139
# 0.00634201827727
# 0.0102891308575
# 0.0045484153218
# 0.0131604122108
# 0.0127318685592
# 0.0060623177134
# 11.5734686953
# 11.4774110441
# 10.6613968501
# 11.1387129108
# 11.5074275715
# 11.2849150301
# 11.4537898114
# 11.2702772701
# 11.2924236827
# 11.8921952168
# 11.1599100719
# 11.550886642
# 10.8680021388
# 11.4093575734
# 11.3130333463
# 10.8694449738
# 5.49828611705
# 5.01202138829
# 6.73592533541
# 9.4129143496
# 5.54916459265
# 4.38850816644
# 8.62222885475
# 13.5791757729
# 17.8191259965
# 6.9675164301
# 6.97130964418
# 8.40398347268
# 5.45078796422
# 10.6439295158
# 10.4239887225
# 6.69368335602

# %%
#Plots with all the data
plt.figure(figsize=(60,10))
plt.plot(date_CS650, EC1_CS650, label = 'WCR 0', linewidth=.5)
plt.plot(date_CS650, EC2_CS650, label = 'WCR 1', linewidth=.5)
plt.plot(date_CS650, EC3_CS650, label = 'WCR 2', linewidth=.5)
plt.plot(date_CS650, EC4_CS650, label = 'WCR 3', linewidth=.5)
plt.plot(date_CS650, EC5_CS650, label = 'WCR 4', linewidth=.5)
plt.plot(date_CS650, EC6_CS650, label = 'WCR 5', linewidth=.5)
plt.plot(date_CS650, EC7_CS650, label = 'WCR 6', linewidth=.5)
plt.plot(date_CS650, EC8_CS650, label = 'WCR 7', linewidth=.5)
plt.plot(date_CS650, EC9_CS650, label = 'WCR 8', linewidth=.5)
plt.plot(date_CS650, EC10_CS650, label = 'WCR 9', linewidth=.5)
plt.plot(date_CS650, EC11_CS650, label = 'WCR A', linewidth=.5)
plt.plot(date_CS650, EC12_CS650, label = 'WCR B', linewidth=.5)
plt.plot(date_CS650, EC13_CS650, label = 'WCR C', linewidth=.5)
plt.plot(date_CS650, EC14_CS650, label = 'WCR D', linewidth=.5)
plt.plot(date_CS650, EC15_CS650, label = 'WCR E', linewidth=.5)
plt.plot(date_CS650, EC16_CS650, label = 'WCR F', linewidth=.5)
legend('South Side EC Averages', 'EC')
plt.show()

plt.figure(figsize=(60,10))
plt.plot(date_CS650, T1_CS650, label = 'WCR 0', linewidth=.5)
plt.plot(date_CS650, T2_CS650, label = 'WCR 1', linewidth=.5)
plt.plot(date_CS650, T3_CS650, label = 'WCR 2', linewidth=.5)
plt.plot(date_CS650, T4_CS650, label = 'WCR 3', linewidth=.5)
plt.plot(date_CS650, T5_CS650, label = 'WCR 4', linewidth=.5)
plt.plot(date_CS650, T6_CS650, label = 'WCR 5', linewidth=.5)
plt.plot(date_CS650, T7_CS650, label = 'WCR 6', linewidth=.5)
plt.plot(date_CS650, T8_CS650, label = 'WCR 7', linewidth=.5)
plt.plot(date_CS650, T9_CS650, label = 'WCR 8', linewidth=.5)
plt.plot(date_CS650, T10_CS650, label = 'WCR 9', linewidth=.5)
plt.plot(date_CS650, T11_CS650, label = 'WCR A', linewidth=.5)
plt.plot(date_CS650, T12_CS650, label = 'WCR B', linewidth=.5)
plt.plot(date_CS650, T13_CS650, label = 'WCR C', linewidth=.5)
plt.plot(date_CS650, T14_CS650, label = 'WCR D', linewidth=.5)
plt.plot(date_CS650, T15_CS650, label = 'WCR E', linewidth=.5)
plt.plot(date_CS650, T16_CS650, label = 'WCR F', linewidth=.5)
legend('South Side T Averages', 'T')
plt.show()

plt.figure(figsize=(60,10))
plt.plot(date_CS650, P1_CS650, label = 'WCR 0', linewidth=.5)
plt.plot(date_CS650, P2_CS650, label = 'WCR 1', linewidth=.5)
plt.plot(date_CS650, P3_CS650, label = 'WCR 2', linewidth=.5)
plt.plot(date_CS650, P4_CS650, label = 'WCR 3', linewidth=.5)
plt.plot(date_CS650, P5_CS650, label = 'WCR 4', linewidth=.5)
plt.plot(date_CS650, P6_CS650, label = 'WCR 5', linewidth=.5)
plt.plot(date_CS650, P7_CS650, label = 'WCR 6', linewidth=.5)
plt.plot(date_CS650, P8_CS650, label = 'WCR 7', linewidth=.5)
plt.plot(date_CS650, P9_CS650, label = 'WCR 8', linewidth=.5)
plt.plot(date_CS650, P10_CS650, label = 'WCR 9', linewidth=.5)
plt.plot(date_CS650, P11_CS650, label = 'WCR A', linewidth=.5)
plt.plot(date_CS650, P12_CS650, label = 'WCR B', linewidth=.5)
plt.plot(date_CS650, P13_CS650, label = 'WCR C', linewidth=.5)
plt.plot(date_CS650, P14_CS650, label = 'WCR D', linewidth=.5)
plt.plot(date_CS650, P15_CS650, label = 'WCR E', linewidth=.5)
plt.plot(date_CS650, P16_CS650, label = 'WCR F', linewidth=.5)
legend('South Side P Averages', 'P')
plt.show()

# %%
#CS215 data
date_CS215 = CS215['TIMESTAMP']
temp1_CS215= CS215['AirTC_1_Avg']
RH1_CS215 = CS215['RH_1_Avg']
temp2_CS215= CS215['AirTC_2_Avg']
RH2_CS215 = CS215['RH_2_Avg']
temp3_CS215= CS215['AirTC_3_Avg']
RH3_CS215 = CS215['RH_3_Avg']
temp4_CS215= CS215['AirTC_4_Avg']
RH4_CS215 = CS215['RH_4_Avg']
temp5_CS215= CS215['AirTC_5_Avg']
RH5_CS215 = CS215['RH_5_Avg']
temp6_CS215= CS215['AirTC_6_Avg']
RH6_CS215 = CS215['RH_6_Avg']
temp7_CS215= CS215['AirTC_7_Avg']
RH7_CS215 = CS215['RH_7_Avg']
temp8_CS215= CS215['AirTC_8_Avg']
RH8_CS215 = CS215['RH_8_Avg']
temp9_CS215= CS215['AirTC_9_Avg']
RH9_CS215 = CS215['RH_9_Avg']
temp10_CS215= CS215['AirTC_10_Avg']
RH10_CS215 = CS215['RH_10_Avg']


#all CS215 sensors 
plt.figure(figsize=(60,10))
plt.plot(date_CS215, temp1_CS215, label = 'Sensor 1', linewidth=.5)
plt.plot(date_CS215, temp2_CS215, label = 'Sensor 2', linewidth=.5)
plt.plot(date_CS215, temp3_CS215, label = 'Sensor 3', linewidth=.5)
plt.plot(date_CS215, temp4_CS215, label = 'Sensor 4', linewidth=.5)
plt.plot(date_CS215, temp5_CS215, label = 'Sensor 5', linewidth=.5)
plt.plot(date_CS215, temp6_CS215, label = 'Sensor 6', linewidth=.5)
plt.plot(date_CS215, temp7_CS215, label = 'Sensor 7', linewidth=.5)
plt.plot(date_CS215, temp8_CS215, label = 'Sensor 8', linewidth=.5)
plt.plot(date_CS215, temp9_CS215, label = 'Sensor 9', linewidth=.5)
plt.plot(date_CS215, temp10_CS215, label = 'Sensor 10', linewidth=.5)
legend('Temp RH Sensors', 'T')
plt.show()




def legend2(title):
    plt.title(title)
    plt.xlabel('Temperature')
    plt.ylabel('Height')
    grd = plt.grid(True)
    plt.xticks(rotation= 60)
    ax = plt.gca()
    legend = ax.legend(loc='upper left')

#Daily average of each sensor for a single day-- HEIGHT IS NOT EXACT, not sure exactly at what height the sensors are set up
def dailyaverage(title, start, finish):
    plt.scatter(sum(temp1_CS215[start:finish]) / 1439, 10)
    plt.scatter(sum(temp2_CS215[start:finish]) / 1439, 20)
    plt.scatter(sum(temp3_CS215[start:finish]) / 1439, 30)
    plt.scatter(sum(temp4_CS215[start:finish]) / 1439, 40)
    plt.scatter(sum(temp5_CS215[start:finish]) / 1439, 50)
    plt.scatter(sum(temp6_CS215[start:finish]) / 1439, 60)
    plt.scatter(sum(temp7_CS215[start:finish]) / 1439, 70)
    plt.scatter(sum(temp8_CS215[start:finish]) / 1439, 80)
    plt.scatter(sum(temp9_CS215[start:finish]) / 1439, 90)
    plt.scatter(sum(temp10_CS215[start:finish]) / 1439, 100)
    legend2(title)
    plt.show()


dailyaverage('9/29/17', 968, 2407)
dailyaverage('10/4/17', 8168, 9607)
dailyaverage('10/15/17', 24008, 25447)
#dailyaverage('10/22/17', 34088, 35527) #-- what is wrong with this one? gives error 'unsupported operand type(s) for +: 'float' and 'str''
#Found that on certain days, some of the sensors do not have values-- they show 100 for both temp and RH 10:49 
dailyaverage('10/30/17', 45608, 47047)
dailyaverage('11/3/17', 51368, 52805)
dailyaverage('11/7/17', 57128, 58567)
dailyaverage('11/11/17', 62888, 64327)


#plt.plot(, temp10_CS215[start:finish], label = 'Sensor 10', linewidth=.5)


type(temp8_CS215[34008])
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# float

# %%
#6AM: [1326::1440], noon: [], 6PM: [], midnight: []
def timetemp(start, interval, title):
    plt.figure(figsize=(40,15))
    plt.plot(date_CS215[start::interval], temp1_CS215[start::interval], label = 'Sensor 1', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp2_CS215[start::interval], label = 'Sensor 2', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp3_CS215[start::interval], label = 'Sensor 3', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp4_CS215[start::interval], label = 'Sensor 4', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp5_CS215[start::interval], label = 'Sensor 5', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp6_CS215[start::interval], label = 'Sensor 6', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp7_CS215[start::interval], label = 'Sensor 7', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp8_CS215[start::interval], label = 'Sensor 8', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp9_CS215[start::interval], label = 'Sensor 9', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp10_CS215[start::interval], label = 'Sensor 10', linewidth = .5)
    legend2(title)
    ax = plt.gca()
    myFmt = mdates.DateFormatter("%Y-%m-%d %H:%M")
    ax.xaxis.set_major_formatter(myFmt)
    ax.xaxis.set_major_locator(mdates.HourLocator(byhour= range(0,24,12)))
    plt.show()

timetemp(1326, 1440, '6AM')
timetemp(1686, 1440, 'Noon')
timetemp(2046, 1440, '6PM')
timetemp(68, 1440, 'Midnight')

def subtractmean1(start, interval, title):
    plt.figure(figsize=(40,15))
    plt.plot(date_CS215[start::interval], temp1_CS215[start::interval]-sum(temp1_CS215[start::interval])/len(temp1_CS215[start::interval]), label = 'Sensor 1', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp2_CS215[start::interval]-sum(temp2_CS215[start::interval])/len(temp2_CS215[start::interval]), label = 'Sensor 2', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp3_CS215[start::interval]-sum(temp3_CS215[start::interval])/len(temp3_CS215[start::interval]), label = 'Sensor 3', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp4_CS215[start::interval]-sum(temp4_CS215[start::interval])/len(temp4_CS215[start::interval]), label = 'Sensor 4', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp5_CS215[start::interval]-sum(temp5_CS215[start::interval])/len(temp5_CS215[start::interval]), label = 'Sensor 5', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp6_CS215[start::interval]-sum(temp6_CS215[start::interval])/len(temp6_CS215[start::interval]), label = 'Sensor 6', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp7_CS215[start::interval]-sum(temp7_CS215[start::interval])/len(temp7_CS215[start::interval]), label = 'Sensor 7', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp8_CS215[start::interval]-sum(temp8_CS215[start::interval])/len(temp8_CS215[start::interval]), label = 'Sensor 8', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp9_CS215[start::interval]-sum(temp9_CS215[start::interval])/len(temp9_CS215[start::interval]), label = 'Sensor 9', linewidth = .5)
    plt.plot(date_CS215[start::interval], temp10_CS215[start::interval]-sum(temp10_CS215[start::interval])/len(temp10_CS215[start::interval]), label = 'Sensor 10', linewidth = .5)
    legend2(title)
    ax = plt.gca()
    myFmt = mdates.DateFormatter("%Y-%m-%d %H:%M")
    ax.xaxis.set_major_formatter(myFmt)
    ax.xaxis.set_major_locator(mdates.HourLocator(byhour= range(0,24,12)))
    plt.show()

subtractmean1(1326, 1440, '6AM substracted average')

# %%
#plot for a certain day, find the start and finish in the excel sheet
def dailyplot(title, start, finish):
    plt.figure(figsize=(40,15))
    plt.plot(date_CS215[start:finish], temp1_CS215[start:finish], label = 'Sensor 1', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp2_CS215[start:finish], label = 'Sensor 2', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp3_CS215[start:finish], label = 'Sensor 3', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp4_CS215[start:finish], label = 'Sensor 4', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp5_CS215[start:finish], label = 'Sensor 5', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp6_CS215[start:finish], label = 'Sensor 6', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp7_CS215[start:finish], label = 'Sensor 7', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp8_CS215[start:finish], label = 'Sensor 8', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp9_CS215[start:finish], label = 'Sensor 9', linewidth=.5)
    plt.plot(date_CS215[start:finish], temp10_CS215[start:finish], label = 'Sensor 10', linewidth=.5)
    legend(title, 'T')
    plt.show()

def dayexample(title, value):
    plt.scatter(temp1_CS215[value], 10)
    plt.scatter(temp2_CS215[value], 20)
    plt.scatter(temp3_CS215[value], 30)
    plt.scatter(temp4_CS215[value], 40)
    plt.scatter(temp5_CS215[value], 50)
    plt.scatter(temp6_CS215[value], 60)
    plt.scatter(temp7_CS215[value], 70)
    plt.scatter(temp8_CS215[value], 80)
    plt.scatter(temp9_CS215[value], 90)
    plt.scatter(temp10_CS215[value], 100)
    legend2(title)
    plt.show()

#for 10/12/17
dayexample('6am', 20051)
dayexample('noon', 20411)
dayexample('6pm', 20771)
dayexample('midnight', 21131)


#Plot for just 10/15/17
dailyplot('test', 24008, 25447)

mean1 = sum(temp1_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean2 = sum(temp2_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean3 = sum(temp3_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean4 = sum(temp4_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean5 = sum(temp5_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean6 = sum(temp6_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean7 = sum(temp7_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean8 = sum(temp8_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean9 = sum(temp9_CS215[24008:25447])/len(temp1_CS215[24008:25447])
mean10 = sum(temp10_CS215[24008:25447])/len(temp1_CS215[24008:25447])
# Out:
# /anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
